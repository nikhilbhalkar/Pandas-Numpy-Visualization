# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10, 200)
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is x lable")
plt.ylabel("This is y data")
plt.title("My graph")
plt.show()

# %%
x = np.random.rand(50)
x
# Out:
# array([0.82906608, 0.50093186, 0.88155807, 0.90890919, 0.98030271,
#        0.10935291, 0.73608609, 0.1189023 , 0.99811032, 0.52348044,
#        0.63970952, 0.282125  , 0.2209113 , 0.2543161 , 0.97985599,
#        0.5136235 , 0.98486643, 0.30784335, 0.31476846, 0.68538636,
#        0.32293076, 0.33284568, 0.78026521, 0.30311845, 0.46372762,
#        0.31768671, 0.96153601, 0.25751823, 0.65147911, 0.79435494,
#        0.56578423, 0.0248742 , 0.82715436, 0.83216198, 0.1718032 ,
#        0.85042313, 0.731515  , 0.64226958, 0.84779994, 0.028419  ,
#        0.6971674 , 0.87272454, 0.72455591, 0.26535364, 0.97231177,
#        0.90330375, 0.47694165, 0.461839  , 0.67155147, 0.20990086])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.35720892, 0.34903936, 0.65879594, 0.98419646, 0.62651527,
#        0.47352672, 0.80315419, 0.28202661, 0.99875092, 0.4194991 ,
#        0.67477675, 0.62633364, 0.88778973, 0.59809669, 0.47776764,
#        0.3606147 , 0.15766773, 0.99652738, 0.49109891, 0.69772909,
#        0.08786525, 0.87834118, 0.15268139, 0.29158608, 0.76686206,
#        0.54303534, 0.65696828, 0.82156476, 0.27133254, 0.44161462,
#        0.445176  , 0.01475047, 0.89408347, 0.40458235, 0.57853994,
#        0.96402612, 0.98528601, 0.31271664, 0.49458799, 0.49525833,
#        0.41331667, 0.62338834, 0.03690957, 0.32358717, 0.36205095,
#        0.25856638, 0.33769094, 0.25317996, 0.20393129, 0.42445374])

# %%
plt.scatter(x,y)

# %%
colours = np.random.rand(50)
sizes  = np.random.rand(50)
plt.scatter(x,y,c=colours,s = sizes*1000,alpha=0.4)
plt.xlabel("X-axis")
plt.ylabel("Y-lable")
plt.title("Bfedeff")
# Out:
# Text(0.5, 1.0, 'Bfedeff')

# %%
x = ['a','b','c','d','e']
y = np.random.rand(5)

# %%
plt.bar(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-lable")
plt.title("Bar ghraph")
# Out:
# Text(0.5, 1.0, 'Bar ghraph')

# %%
plt.barh(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-lable")
plt.title("Bar ghraph")
# Out:
# Text(0.5, 1.0, 'Bar ghraph')

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y,'--r')
plt.xlabel("This is x lable")
plt.ylabel("This is y data")
plt.title("My graph")
plt.grid()
plt.show()

# %%
x = np.random.rand(50)
y= np.random.rand(50)
colours = np.random.rand(50)
sizes  = np.random.rand(50)
plt.scatter(x,y,c='#A64D13',s = sizes*1000,alpha=0.4,marker='x')
plt.xlabel("X-axis")
plt.ylabel("Y-lable")
plt.title("Bfedeff")
# Out:
# Text(0.5, 1.0, 'Bfedeff')

# %%
x= [4,5,6,8,9,34,54]
y=[6,7,8,90,50,20,10]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,1,2,3,6,7,1,2,3]

# %%
plt.hist(data)
plt.show()

# %%
x= [4,5,6,7,8,9]
y=[60,30,80,19,40,1]
color = ['red','blue','yellow','orange','black','pink']
plt.scatter(x,y,c=color)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()
