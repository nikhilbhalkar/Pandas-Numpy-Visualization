# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.read_csv("titanic.csv")
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df2.fillna("sudh")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3 = pd.read_csv("Crop_recommendation.csv")
df3
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
g = df3.groupby("label")
g

# %%
g.mean()
# Out:
#                   N       P       K  temperature   humidity        ph  \
# label
# apple         20.80  134.22  199.89    22.630942  92.333383  5.929663
# banana       100.23   82.01   50.05    27.376798  80.358123  5.983893
# blackgram     40.02   67.47   19.24    29.973340  65.118426  7.133952
# chickpea      40.09   67.79   79.92    18.872847  16.860439  7.336957
# coconut       21.98   16.93   30.59    27.409892  94.844272  5.976562
# coffee       101.20   28.74   29.94    25.540477  58.869846  6.790308
# cotton       117.77   46.24   19.56    23.988958  79.843474  6.912675
# grapes        23.18  132.53  200.11    23.849575  81.875228  6.025937
# jute          78.40   46.86   39.99    24.958376  79.639864  6.732778
# kidneybeans   20.75   67.54   20.05    20.115085  21.605357  5.749411
# lentil        18.77   68.36   19.41    24.509052  64.804785  6.927932
# maize         77.76   48.44   19.79    22.389204  65.092249  6.245190
# ...

# %%
g.sum()
# Out:
#                  N      P      K  temperature     humidity          ph  \
# label
# apple         2080  13422  19989  2263.094241  9233.338288  592.966293
# banana       10023   8201   5005  2737.679831  8035.812258  598.389318
# blackgram     4002   6747   1924  2997.333968  6511.842559  713.395163
# chickpea      4009   6779   7992  1887.284675  1686.043942  733.695662
# coconut       2198   1693   3059  2740.989217  9484.427181  597.656213
# coffee       10120   2874   2994  2554.047682  5886.984630  679.030827
# cotton       11777   4624   1956  2398.895790  7984.347425  691.267550
# grapes        2318  13253  20011  2384.957512  8187.522752  602.593668
# jute          7840   4686   3999  2495.837583  7963.986421  673.277757
# kidneybeans   2075   6754   2005  2011.508469  2160.535673  574.941059
# lentil        1877   6836   1941  2450.905240  6480.478468  692.793157
# maize         7776   4844   1979  2238.920391  6509.224945  624.518972
# ...

# %%
g.max()
# Out:
#                N    P    K  temperature   humidity        ph    rainfall
# label
# apple         40  145  205    23.996862  94.920481  6.499227  124.983162
# banana       120   95   55    29.908885  84.978492  6.490074  119.847970
# blackgram     60   80   25    34.946616  69.961000  7.775306   74.915595
# chickpea      60   80   85    20.995022  19.969789  8.868741   94.781896
# coconut       40   30   35    29.869083  99.981876  6.470466  225.632366
# coffee       120   40   35    27.923744  69.948073  7.493192  199.473564
# cotton       140   60   25    25.992374  84.876690  7.994680   99.931008
# grapes        40  145  205    41.948657  83.983517  6.499605   74.915062
# jute         100   60   45    26.985822  89.891065  7.488014  199.836291
# kidneybeans   40   80   25    24.923601  24.969699  5.998125  149.744103
# lentil        40   80   25    29.944139  69.923759  7.841496   54.939377
# maize        100   60   25    26.549864  74.829137  6.995844  109.751538
# ...

# %%
g.max()['rainfall']
# Out:
# label
# apple          124.983162
# banana         119.847970
# blackgram       74.915595
# chickpea        94.781896
# coconut        225.632366
# coffee         199.473564
# cotton          99.931008
# grapes          74.915062
# jute           199.836291
# kidneybeans    149.744103
# lentil          54.939377
# maize          109.751538
# mango          100.812466
# mothbeans       74.443307
# mungbean        59.872321
# muskmelon       29.866814
# orange         119.694658
# papaya         248.859299
# pigeonpeas     198.829881
# pomegranate    112.475094
# rice           298.560117
# watermelon      59.759800
# Name: rainfall, dtype: float64

# %%
g.max().transpose()
# Out:
# label             apple      banana  blackgram   chickpea     coconut  \
# N             40.000000  120.000000  60.000000  60.000000   40.000000
# P            145.000000   95.000000  80.000000  80.000000   30.000000
# K            205.000000   55.000000  25.000000  85.000000   35.000000
# temperature   23.996862   29.908885  34.946616  20.995022   29.869083
# humidity      94.920481   84.978492  69.961000  19.969789   99.981876
# ph             6.499227    6.490074   7.775306   8.868741    6.470466
# rainfall     124.983162  119.847970  74.915595  94.781896  225.632366
#
# label            coffee      cotton      grapes        jute  kidneybeans  ...  \
# N            120.000000  140.000000   40.000000  100.000000    40.000000  ...
# P             40.000000   60.000000  145.000000   60.000000    80.000000  ...
# K             35.000000   25.000000  205.000000   45.000000    25.000000  ...
# temperature   27.923744   25.992374   41.948657   26.985822    24.923601  ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df5 = df[['Survived','Pclass','Name']][0:5]
df5
# Out:
#     Survived  Pclass                                               Name
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6          0       1                            McCarthy, Mr. Timothy J
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth

# %%
df6 = df[['Survived','Pclass','Name']][5:10]
df6
# Out:
#     Survived  Pclass                                      Name
# 21         1       2                     Beesley, Mr. Lawrence
# 23         1       1              Sloper, Mr. William Thompson
# 27         0       1            Fortune, Mr. Charles Alexander
# 52         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54         0       1            Ostby, Mr. Engelhart Cornelius

# %%
df7 = pd.concat([df5,df6] , axis=1)
df7
# Out:
#     Survived  Pclass                                               Name  \
# 1        1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3        1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6        0.0     1.0                            McCarthy, Mr. Timothy J
# 10       1.0     3.0                    Sandstrom, Miss. Marguerite Rut
# 11       1.0     1.0                           Bonnell, Miss. Elizabeth
# 21       NaN     NaN                                                NaN
# 23       NaN     NaN                                                NaN
# 27       NaN     NaN                                                NaN
# 52       NaN     NaN                                                NaN
# 54       NaN     NaN                                                NaN
#
#     Survived  Pclass                                      Name
# 1        NaN     NaN                                       NaN
# ...

# %%
df7.fillna("nik")
# Out:
#    Survived Pclass                                               Name  \
# 1       1.0    1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3       1.0    1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6       0.0    1.0                            McCarthy, Mr. Timothy J
# 10      1.0    3.0                    Sandstrom, Miss. Marguerite Rut
# 11      1.0    1.0                           Bonnell, Miss. Elizabeth
# 21      nik    nik                                                nik
# 23      nik    nik                                                nik
# 27      nik    nik                                                nik
# 52      nik    nik                                                nik
# 54      nik    nik                                                nik
#
#    Survived Pclass                                      Name
# 1       nik    nik                                       nik
# 3       nik    nik                                       nik
# ...

# %%
data1 = pd.DataFrame({
    "key1":[1,2,3,4,5],
    "key2":[4,5,6,7,8],
    "key3":[3,4,5,6,6]
    
})
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     6

# %%
data2 = pd.DataFrame({
    "key1":[1,2,36,4,57],
    "key4":[4,53,6,7,8],
    "key5":[23,4,5,6,6]
    
})
data2
# Out:
#    key1  key4  key5
# 0     1     4    23
# 1     2    53     4
# 2    36     6     5
# 3     4     7     6
# 4    57     8     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3     4    23
# 1     2     5     4    53     4
# 2     4     7     6     7     6

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3   4.0  23.0
# 1     2     5     4  53.0   4.0
# 2     3     6     5   NaN   NaN
# 3     4     7     6   7.0   6.0
# 4     5     8     6   NaN   NaN

# %%
pd.merge(data1,data2,how='right',on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     4    23
# 1     2   5.0   4.0    53     4
# 2    36   NaN   NaN     6     5
# 3     4   7.0   6.0     7     6
# 4    57   NaN   NaN     8     6

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   4.0  23.0
# 1     2   5.0   4.0  53.0   4.0
# 2     3   6.0   5.0   NaN   NaN
# 3     4   7.0   6.0   7.0   6.0
# 4     5   8.0   6.0   NaN   NaN
# 5    36   NaN   NaN   6.0   5.0
# 6    57   NaN   NaN   8.0   6.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1     4    23
# 1        1     4     3       2    53     4
# 2        1     4     3      36     6     5
# 3        1     4     3       4     7     6
# 4        1     4     3      57     8     6
# 5        2     5     4       1     4    23
# 6        2     5     4       2    53     4
# 7        2     5     4      36     6     5
# 8        2     5     4       4     7     6
# 9        2     5     4      57     8     6
# 10       3     6     5       1     4    23
# 11       3     6     5       2    53     4
# 12       3     6     5      36     6     5
# 13       3     6     5       4     7     6
# 14       3     6     5      57     8     6
# 15       4     7     6       1     4    23
# 16       4     7     6       2    53     4
# 17       4     7     6      36     6     5
# 18       4     7     6       4     7     6
# 19       4     7     6      57     8     6
# 20       5     8     6       1     4    23
# ...

# %%
data1 = pd.DataFrame({
    "key1":[1,2,3,4,5],
    "key2":[4,5,6,7,8],
    "key3":[3,4,5,6,6],},
    index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({
    "key11":[1,2,36,4,57],
    "key44":[4,53,6,7,8],
    "key55":[23,4,5,6,6]},
    index = ['a','b','h','i','j']
    
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     5     8     6

# %%
data2
# Out:
#    key11  key44  key55
# a      1      4     23
# b      2     53      4
# h     36      6      5
# i      4      7      6
# j     57      8      6

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key44  key55
# a   1.0   4.0   3.0      1      4     23
# b   2.0   5.0   4.0      2     53      4
# h   NaN   NaN   NaN     36      6      5
# i   NaN   NaN   NaN      4      7      6
# j   NaN   NaN   NaN     57      8      6

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key44  key55
# a     1     4     3      1      4     23
# b     2     5     4      2     53      4

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key44  key55
# a   1.0   4.0   3.0    1.0    4.0   23.0
# b   2.0   5.0   4.0    2.0   53.0    4.0
# c   3.0   6.0   5.0    NaN    NaN    NaN
# d   4.0   7.0   6.0    NaN    NaN    NaN
# e   5.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN   36.0    6.0    5.0
# i   NaN   NaN   NaN    4.0    7.0    6.0
# j   NaN   NaN   NaN   57.0    8.0    6.0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def convertTO(x):
    return x*80
#df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)
df['Fare_INR'] = df['Fare'].apply(convertTO)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Fare_INR
# 1       0  PC 17599  71.2833   C85        C  5702.664
# 3       0    113803  53.1000  C123        S  4248.000
# 6       0     17463  51.8625   E46        S  4149.000
# 10      1   PP 9549  16.7000    G6        S  1336.000
# ...

# %%
df['Name_length'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Fare_INR  Name_length
# 1       0  PC 17599  71.2833   C85        C  5702.664           51
# 3       0    113803  53.1000  C123        S  4248.000           44
# 6       0     17463  51.8625   E46        S  4149.000           23
# ...

# %%
def FrameConvert(x):
    if x<10:
        return "cheep"
    elif x>= 10 and x<20:
        return "mid"
    else :
        return "high"

# %%
df['cat_fare'] = df['Fare'].apply(FrameConvert)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Fare_INR  Name_length cat_fare
# 1       0  PC 17599  71.2833   C85        C  5702.664           51     high
# 3       0    113803  53.1000  C123        S  4248.000           44     high
# 6       0     17463  51.8625   E46        S  4149.000           23     high
# ...
